# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

import os
import pandas as pd

import numpy as np

# %%
data_dir = '/cephfs/pic.es/astro/scratch/lcabayol/Flux_estimation/img_NB685'
img_fname = 'red_NightlyR11.paucam.12772.1003.0141.FT_NB615_NB685.2469553.std.01.fits'

img_path = os.path.join(data_dir, img_fname)

# %%
from astropy.io import fits
from sqlalchemy.engine import create_engine
from sqlalchemy import *
from sqlalchemy.orm import *

engine = create_engine('postgresql://readonly@db03.pau.pic.es/dm')

# %%
def DB_query(band,fn):

    query = ("""SELECT fa.ref_id, cm.ra, cm.dec, i.filename, m.exp_num,fa.image_id, cm.r50, cm.sersic_n_gim2d, fa.flux, fa.flux_error, fa.aperture_a, fa.aperture_b, fa.aperture_theta, i.psf_fwhm, i.filter, fa.aperture_x, fa.aperture_y, cm."I_auto" """+
        """FROM mosaic as m """ +
        """JOIN image as i ON i.mosaic_id = m.id """+
        """JOIN forced_aperture as fa ON fa.image_id = i.id """+
        """JOIN COSMOS as cm ON cm.paudm_id = fa.ref_id """ +
        """WHERE fa.production_id = 948 """+
        """AND cm."I_auto" < 23 """+
        """AND cm.r50 IS NOT NULL """+
        """AND cm.zspec !=0 """+
        """AND i.filter = '%s' """%band+
        """AND sersic_n_gim2d > 0 """+
        """AND r50 > 0 """+
        """AND i.filename = '%s'"""%fn)
    return query

# %%
hdul = fits.open(img_path)
img = hdul[0].data
band = 'NB685'
query = DB_query(band,img_fname)

with engine.begin() as conn:
    conn.execute("SET TRANSACTION ISOLATION LEVEL SERIALIZABLE READ ONLY DEFERRABLE")
    sources = pd.read_sql(query, conn)

# %%
sources = sources.loc[:10].copy()

# %%
sources['interv'] = np.zeros(shape = len(sources))
sources.interv.where(sources.exp_num < 7582, 1, inplace=True)
sources = sources.rename(columns = {'filter':'band'})
sources['interv'] = sources.interv.astype(np.int)

# %%
coords_pix = pd.DataFrame(np.c_[sources.aperture_y, sources.aperture_x], columns = ['x','y'])

# %%
met = sources[['ref_id','r50','sersic_n_gim2d','psf_fwhm','aperture_x','aperture_y','aperture_a','aperture_b','I_auto','band','aperture_theta','interv']]

# %%
import lumos
model_path = '/cephfs/pic.es/astro/scratch/lcabayol/Flux_estimation/models/lumos_after/Lumos_v9b_smallert_v2_63.pt'
net = lumos.Lumos_net(model_path)



#background_img(self, img, coords_pix, metadata)

# %%
df_pred = net._photometry_img( img, coords_pix, met)
# Out:
# NB685_1
# /nfs/pic.es/user/l/lcabayol/lumos/lumos/lumos.py:165: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   metadata['band'] = self._internal_naming(metadata.band.values[0], interv)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-55-c41b7834f54d> in <module>
# ----> 1 df_pred = net._photometry_img( img, coords_pix, met)
#
# ~/lumos/lumos/lumos.py in _photometry_img(self, img, coords_pix, metadata)
#     165         metadata['band'] = self._internal_naming(metadata.band.values[0], interv)
#     166
# --> 167         pred = self._photometry_cutouts(stamps,profiles, metadata)
#     168
#     169         return pred
#
# ~/lumos/lumos/lumos.py in _photometry_cutouts(self, net_inp_img, net_inp_prof, metadata)
#     135         """Determine the bakground for the postage stamps."""
#     136
# --> 137         dset  = self._asdataset(net_inp_img, net_inp_prof, metadata)
#     138         loader = DataLoader(dset, batch_size=self.batch_size, \
#     139                             shuffle=False)
#
# ~/lumos/lumos/lumos.py in _asdataset(self, cutouts, profiles, metadata)
#     125
#     126         add_input = metadata.astype(np.float32, copy=False)
# --> 127         coord = torch.Tensor(np.c_[metadata.y.values, metadata.x.values]).unsqueeze(1)
#     128         band = metadata.band.values
#     129         I_auto = torch.tensor(metadata.I_auto.values).unsqueeze(1)
#
# /cephfs/pic.es/astro/scratch/lcabayol/miniconda/envs/MLenv/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5137             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5138                 return self[name]
# -> 5139             return object.__getattribute__(self, name)
#    5140
#    5141     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 